# %%
from PIL import Image

# %%
# Text Variables
Header = 'This resume was generated entirely in Python. check my github page.'
Name = 'Leonardo Zamora Leiva'
Title = 'Biochemist and Bioinformatic'
ContactHeader = 'Contact Information'
Contact = '                           Quilpué, Chile\n            \n                        +56 9-51784481\n \nlinkedin.com/in/leonardo-zamora-leiva-84a82710b/'
ProjectsHeader = 'Relevant Projects Experience'
ProjectOneTitle = 'Workflow development for PhD proyect'
ProjectOneDesc = '- Develop workflow for data visualization and analysis with python.\n- Develop image deployment of genomic information files on python and R.\n- Modify existing bioinformatic tools to improve their development with\ncustom data (Python).'
ProjectTwoTitle = 'Data downloading from FTP server for Phylogenomic analysis'
ProjectTwoDesc = '- Conecting to FTP server \n- Use regular expressions to stadarize data\n- Cleaned and combined several tables using pandas library in Python\n- Used PDE and visualization to determine correlations for future study'
ProjectThreeTitle = 'Minor personal proyects'
ProjectThreeDesc = '- Deploy an user interface app that generate random objects'
Portfolio = 'Portfolio: https://github.com/LeonardoZamoraLeiva'
WorkHeader = 'Working experience'
WorkOneTitle = 'Ocular Labs SpA. / Graphene Oxide production manager'
WorkOneTime = '3/2019 - 3/2020'
WorkOneDesc = ' - Generation and implementation of a method for the production of graphene\noxide'
WorkTwoTitle = 'Second Company / Second Position'
WorkTwoTime = '2/2007-8/2013'
WorkTwoDesc = '- Led team of over 100 full-time and contract staff\n- Helped create branding and messaging for weekly content\n- Created/directed musical elements at weekly events for up to 10,000 people'
#Education
EduHeader = 'EDUCATION'
EduOneTitle = 'Pontificia Universidad Católica de Valparaíso, Biochemistry'
EduOneTime = '2008-2015'
EduTwoTitle = 'PUCV/UTFSM, PhD on Biotechnology'
EduTwoTime = '2017-to Date'
EduThreeTitle = '2021 Complete Python Bootcamp From Zero to Hero in Python'
EduThreeTime = '2021'
ResumeTitle = 'How I am'
Resume = 'I am a very proactive person looking to expand \nmy frontiers into the IT area. I have developed \nmy professional career as a bioinformatician, \nacquiring diverse skills, mainly with python. \nI have developed workflows that have reduce \nthe analysis time in biological data.'
SkillsHeader = 'Skills'
SkillsDesc = '- Python:\n   - Pandas\n   - Data Visualization\n   - NumPy\n   - Data Cleaning\n \n- R'
SkillsDesc2 = '- Web development:\n   - JavaScript\n   - HTML\n   -CSS\n   - Bootstrap'
#Extras
#ExtrasTitle = '        My goals\nData Scientist Path'
#ExtrasDesc = 'Continue my learning in popular data science \nlanguages, data cleaning and manipulation,\nmachine learning and statistical analysis.'
#CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(9, 11))

# Decorative Lines
ax.axvline(x=.6, ymax=0.8, color='#007ACC', alpha=0.0, linewidth=0)
plt.axvline(x=.9, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=0.2, xmin=0, xmax=1, color='#ffffff', linewidth=10)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,1), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(ContactHeader, (.68,.90), weight='regular', fontsize=15, color='#ffffff')
plt.annotate(Contact, (.64,.81), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(ProjectsHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.76), weight='regular', fontsize=8)
plt.annotate(ProjectTwoTitle, (.02,.73), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.66), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.63), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.61), weight='regular', fontsize=9)
plt.annotate(Portfolio, (.02,.55), weight='bold', fontsize=10)
#Working experience
#plt.annotate(WorkHeader, (.02,.52), weight='bold', fontsize=12, color='#58C1B2')
#plt.annotate(WorkOneTitle, (.02,.49), weight='bold', fontsize=10)
#plt.annotate(WorkOneTime, (.02,.47), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkOneDesc, (.04,.44), weight='regular', fontsize=9)
#plt.annotate(WorkTwoTitle, (.02,.4), weight='bold', fontsize=10)
#plt.annotate(WorkTwoTime, (.02,.385), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkTwoDesc, (.04,.337), weight='regular', fontsize=9)
#plt.annotate(WorkThreeTitle, (.02,.295), weight='bold', fontsize=10)
#plt.annotate(WorkThreeTime, (.02,.28), weight='regular', fontsize=9, alpha=.6)
#plt.annotate(WorkThreeDesc, (.04,.247), weight='regular', fontsize=9)
#Education
plt.annotate(EduHeader, (.02,.380), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.350), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.330), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoTitle, (.02,.300), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.280), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduThreeTitle, (.02,.250), weight='bold', fontsize=10)
plt.annotate(EduThreeTime, (.02,.230), weight='regular', fontsize=9, alpha=.6)
#Resume
plt.annotate(ResumeTitle, (.74,.73), weight='bold', fontsize=15, color='#ffffff')
plt.annotate(Resume, (.61,.58), weight='regular', fontsize=10, color='#ffffff')
#Skills
plt.annotate(SkillsHeader, (.74,.50), weight='bold', fontsize=15, color='#ffffff')
plt.annotate(SkillsDesc, (.62,.34), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc2, (.81,.38), weight='regular', fontsize=10, color='#ffffff')
#Extra
#plt.annotate(ExtrasTitle, (.67,.38), weight='bold', fontsize=15, color='#ffffff')
#plt.annotate(ExtrasDesc, (.62,.30), weight='regular', fontsize=10, color='#ffffff')
#plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('qr-code.png')
imagebox = OffsetImage(arr_code, zoom=0.06)
ab = AnnotationBbox(imagebox, (0.25, 0.47))
ax.add_artist(ab)

plt.savefig('resumeexample.pdf', dpi=300, bbox_inches='tight')
